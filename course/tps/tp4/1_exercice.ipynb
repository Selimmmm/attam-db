# %% [markdown]
# # Exercice
#
# - En générant des données aléatoires (ou en écrivant en dur) dans le langage de votre choix, reproduire le schéma Northwind en respectant les types (composé uniquement des tables `categories`, `products` et `suppliers`, on ne s'intéresse pas aux autres tables).

# %%
import pandas as pd

df = pd.DataFrame()
